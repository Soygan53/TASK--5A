# %%
from faker import Faker
import pandas as pd
import numpy as np
import time

faker=Faker()
e_mail_adresses=[]
passwords=[]
e_mail_adresses2=[]
passwords2=[]

for i in range(10000):
    e_mail_adresses.append(faker.email())
    passwords.append(faker.password())

df1=pd.DataFrame(e_mail_adresses, columns =['E-Mail Adresses'])
df2= pd.DataFrame(passwords, columns =['Passwords'])

A=pd.concat([df1,df2],axis=1)
for i in range(10000):
    e_mail_adresses2.append(faker.email())
    passwords2.append(faker.password())

df3=pd.DataFrame(e_mail_adresses2, columns =['E-Mail Adresses'])
df4= pd.DataFrame(passwords2, columns =['Passwords'])

C=pd.concat([df1,df2],axis=1)

start_time=time.time()

for k in range (10000):
    for i in range (10000):
        if e_mail_adresses[i]==e_mail_adresses2[k]:
            print(e_mail_adresses[i])
end_time=time.time()
print(end_time-start_time)
# Out:
# williamsjames@hotmail.com
# gwilliams@hotmail.com
# qmiller@hotmail.com
# fsmith@gmail.com
# fsmith@gmail.com
# eingram@yahoo.com
# krichardson@yahoo.com
# ajohnson@hotmail.com
# christopher99@gmail.com
# stephanie78@yahoo.com
# ldavis@gmail.com
# kimberly04@hotmail.com
# martinezbrian@gmail.com
# amysmith@hotmail.com
# chall@gmail.com
# brian23@gmail.com
# thompsonmichael@gmail.com
# nroberts@yahoo.com
# david60@hotmail.com
# grivera@hotmail.com
# jlewis@yahoo.com
# xlee@gmail.com
# ismith@yahoo.com
# bpatel@yahoo.com
# ldavis@hotmail.com
# eanderson@gmail.com
# qparker@gmail.com
# hilljennifer@hotmail.com
# hsmith@yahoo.com
# hsmith@yahoo.com
# dbrown@yahoo.com
# awilson@hotmail.com
# nicholas98@gmail.com
# stacy37@hotmail.com
# krodriguez@yahoo.com
# james91@yahoo.com
# john63@yahoo.com
# jessica75@hotmail.com
# rmartinez@hotmail.com
# hollysmith@hotmail.com
# wsmith@yahoo.com
# psmith@hotmail.com
# usmith@yahoo.com
# khill@hotmail.com
# jessica99@hotmail.com
# ...
